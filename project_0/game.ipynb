# %%
import game_v2
# Out:
# Число должно быть больше!
# Число должно быть больше!
# Число должно быть больше!
# Число должно быть меньше!
# Число должно быть больше!
# Вы угадали число! Это число = 83, за 6 попыток

# %%
game_v2.score_game(game_v2.random_predict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 game_v2.score_game(game_v2.random_predict)
#
# NameError: name 'game_v2' is not defined

# %% [markdown]
# # Игра угадай число

# %%
from game_v2 import score_game
from game_v2 import random_predict
score_game(random_predict) #вызов функции
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 from game_v2 import score_game
# ----> 2 from game_v2 import random_predict
#       3 score_game(random_predict) #вызов функции
#
# ImportError: cannot import name 'random_predict' from 'game_v2' (c:\Users\User\GIT\python-training\game_v2.py)

# %%
n = 10
z = n
n = 5
